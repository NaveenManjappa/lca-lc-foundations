# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model(model="gemini-3.1-flash-lite", temperature=0.5,model_provider="google_genai")

# %%
from langchain.agents import create_agent
agent = create_agent(model=model)

# %%
from langchain.messages import HumanMessage
question = HumanMessage(content="My name is John and my favourite color is blue")

response = agent.invoke(
  {"messages":[question]} 
)

# %%
from pprint import pprint
pprint(response)
# Out:
# {'messages': [HumanMessage(content='My name is John and my favourite color is blue', additional_kwargs={}, response_metadata={}, id='bf461715-a0d7-401b-83a1-223bd7e89c45'),
#               AIMessage(content=[{'type': 'text', 'text': 'It’s nice to meet you, John! Blue is a fantastic choice—it’s such a calming and versatile color. \n\nIs there a specific shade of blue you like best, like navy, sky blue, or maybe royal blue?', 'extras': {'signature': 'EjQKMgEMOdbHwmbzwgENXdvJWGsTjZLftWcYcAxErftF/Ehywb1T8CiXmh/7bDxuo5Wk6FWQ'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019eebc0-62e2-7ed1-b558-00f6836edddd-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 50, 'total_tokens': 61, 'input_token_details': {'cache_read': 0}})]}

# %%
question = HumanMessage(content="What is my name and favourite color?")
response = agent.invoke(
  {"messages":[question]} 
)
pprint(response)
# Out:
# {'messages': [HumanMessage(content='What is my name and favourite color?', additional_kwargs={}, response_metadata={}, id='5da00c8e-0c68-4c90-8c3e-4b6e0d3fe552'),
#               AIMessage(content=[{'type': 'text', 'text': "I don’t know your name or your favorite color yet! Since I am an AI, I don't have access to your personal information unless you have shared it with me in this specific conversation.\n\nIf you tell me what they are, I’ll be happy to remember them for the rest of our chat!", 'extras': {'signature': 'EjQKMgEMOdbH/PdC5a3CAf3MafjJeTvdJFXQGd1xdWHyCz+nBH7E3HsZDBpfp207aWKxsp7s'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019eebc1-43ad-7802-a27c-2ad1cf493893-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 9, 'output_tokens': 65, 'total_tokens': 74, 'input_token_details': {'cache_read': 0}})]}

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver
agent = create_agent(model=model, checkpointer=InMemorySaver())

# %%
from langchain.messages import HumanMessage
question = HumanMessage(content="Hello,my name is John and my favourite color is blue")
config = {"configurable":{"thread_id":"1"}}
response = agent.invoke(
  {"messages":[question]},
  config=config
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello,my name is John and my favourite color is blue', additional_kwargs={}, response_metadata={}, id='228136fb-8269-4197-8a66-faeae7decc4f'),
#               AIMessage(content=[{'type': 'text', 'text': 'Hello, John! It’s nice to meet you. Blue is a fantastic choice—it’s often associated with calmness, the sky, and the ocean. \n\nIs there a specific shade of blue you like best, like navy, sky blue, or perhaps royal blue?', 'extras': {'signature': 'EjQKMgEMOdbHwrCBLKoRFapTUIT77Vn7bs75dCdS5swhwLJVxkRGTp2DFgR/W2TBUm2zXaBC'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019eebc5-978f-78d0-a731-ec2d0f2189d4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 57, 'total_tokens': 70, 'input_token_details': {'cache_read': 0}})]}

# %%
question = HumanMessage(content="What is my name and favourite color?")
response = agent.invoke(
  {"messages":[question]} ,
  config=config
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello,my name is John and my favourite color is blue', additional_kwargs={}, response_metadata={}, id='228136fb-8269-4197-8a66-faeae7decc4f'),
#               AIMessage(content=[{'type': 'text', 'text': 'Hello, John! It’s nice to meet you. Blue is a fantastic choice—it’s often associated with calmness, the sky, and the ocean. \n\nIs there a specific shade of blue you like best, like navy, sky blue, or perhaps royal blue?', 'extras': {'signature': 'EjQKMgEMOdbHwrCBLKoRFapTUIT77Vn7bs75dCdS5swhwLJVxkRGTp2DFgR/W2TBUm2zXaBC'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019eebc5-978f-78d0-a731-ec2d0f2189d4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 57, 'total_tokens': 70, 'input_token_details': {'cache_read': 0}}),
# ...
